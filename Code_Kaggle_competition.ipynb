# %%
import pandas as pd
import numpy as np
from scipy import stats
import datetime
import seaborn as sns
from catboost import CatBoostClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.preprocessing import LabelEncoder

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

print('Train Shape:', train.shape)
print('Test Shape:', test.shape)
train.head()
# Out:
# Train Shape: (80176, 14)
# Test Shape: (34365, 13)
#    Unnamed: 0                                   date          org  \
# 0           0         Mon, 6 Nov 2017 11:13:45 +0100        reply
# 1           1        Wed, 14 Feb 2018 11:00:16 -0000          edm
# 2           2         Wed, 6 Jul 2016 19:53:37 +0000  usebackpack
# 3           3        Fri, 11 Oct 2019 11:25:40 +0200     granular
# 4           4  Tue, 07 Nov 2017 11:07:18 +0000 (UTC)       github
#
#             tld  ccs  bcced              mail_type  images  urls  salutations  \
# 0       ebay.in    0      0  multipart/alternative      35   120            0
# 1  efinmail.com    0      0  multipart/alternative       1     7            0
# 2           com    0      0              text/html       4    17            0
# 3            ai    0      0        multipart/mixed       0     0            0
# 4           com    1      0  multipart/alternative       2    11            0
#
#    designation  chars_in_subject  chars_in_body  label
# 0            0              49.0          80027      2
# 1            0             107.0           2961      1
# 2            0              35.0          25149      1
# 3            0              15.0         635296      1
# 4            0              49.0           2355      1

# %%
df = pd.concat([train, test])
df.shape
# Out:
# (114541, 14)

# %%
labels = {0: 'Updates', 1: 'Personal', 2: 'Promotions', 3: 'Forums', 4: 'Purchases', 5: 'Travel', 6: 'Spam', 7: 'Social'}
df['label_type'] = df.label.map(labels)
df.label_type.value_counts()
# Out:
# Personal      37195
# Updates       17995
# Forums        10727
# Promotions     8567
# Social         5042
# Purchases       357
# Spam            152
# Travel          141
# Name: label_type, dtype: int64

# %%
# #### Date Correction
df['date_length'] = df.date.str.len()
df.groupby('date_length').agg({'date': ['min', 'max', 'count']})
# Out:
#                                                     date  \
#                                                      min
# date_length
# 18                                    26 Dec 13 18:48:01
# 20                                  11-MAR-2018 20:40:58
# 24                              Fri, 5 Jul 2013 13:30:59
# 25                             1 Apr 2014 12:59:18 -0000
# 26                            01 Apr 2018 18:50:30 +0530
# 28                          Fri, 9 Nov 2012 06:11:45 GMT
# 29                         Fri, 16 Jun 2017 08:44:58 GMT
# 30                        Fri, 1 Apr 2016 00:30:09 +0000
# 31                       Fri,  2 Aug 2019 12:00:13 +0000
# 32                      Sun, 08 Sep 2019 18:42:09 +0000
# 36                  Fri, 1 Apr 2016 13:39:17 -0500 (CDT)
# 37                 Fri,  1 Dec 2017 15:50:11 +0530 (IST)
# 38                Fri,  4 Oct 2019 11:30:46 +0200 (CEST)
# 39               Mon, 15 Jul 2013 22:19:20 +0530 (INDIA)
# 42            Fri, 5 Sep 2014 14:47:01 +0530 (GMT+05:30)
# 43           Fri, 12 Jun 2020 16:30:32 +0800 (GMT+08:00)
#
#
#                                                      max  count
# date_length
# 18                                    26 Dec 13 18:48:01      1
# 20                                  11-MAR-2018 20:40:58      2
# 24                              Wed, 4 Sep 2013 19:18:20     12
# 25                             Wed, 21 Mar 2018 17:50:26    681
# 26                            Thu, 28 Aug 2014 14:38:35    2312
# 28                          Wed, 6 Feb 2013 16:40:36 GMT      6
# 29                         Wed, 28 Oct 2020 09:20:57 GMT    130
# 30                        Wed, 9 Sep 2020 19:00:30 +0000  18207
# 31                       Wed, 31 Oct 2018 20:09:58 +0000  73143
# 32                      Sun, 08 Sep 2019 18:42:09 +0000       2
# 36                  Wed, 9 Sep 2015 10:20:32 +0000 (UTC)   2683
# 37                 Wed, 8 Apr 2020 00:16:16 +0200 (CEST)  16869
# 38                Wed, 31 May 2017 15:10:19 +0200 (CEST)    445
# 39               Sat, 13 Jul 2013 22:56:45 +0530 (INDIA)      4
# 42            Fri, 5 Sep 2014 14:47:01 +0530 (GMT+05:30)      2
# 43           Wed, 31 Oct 2012 14:08:07 +0000 (GMT+00:00)     42

# %%
df['local_date'] = df.date

# Removing Day Name
for day in ['Mon,', 'Tue,', 'Wed,', 'Thu,', 'Fri,', 'Sat,', 'Sun,']:
    df['local_date'] = df.local_date.apply(lambda x: x.replace(day, ''))

# %%
# Removing Timezones
df['local_date'] = df.local_date.apply(lambda x: x.split('+')[0]) 
df['local_date'] = df.local_date.apply(lambda x: x.split('-0')[0])
df['local_date'] = df.local_date.apply(lambda x: x.split('GMT')[0])

# %%
# Other Corrections
df['local_date'] = df.local_date.apply(lambda x: ' '.join(x.split())) # removing duplicate spaces
df['local_date'] = df.local_date.apply(lambda x: x.replace('-', ' ')) # removing dashes in date
df['local_date'] = df.local_date.str.strip() # removing extra spaces from ends

# %%
df['date_length'] = df.local_date.str.len()
df.groupby('date_length').agg({'local_date': ['min', 'max', 'count']})
# Out:
#                        local_date
#                               min                   max  count
# date_length
# 18             26 Dec 13 18:48:01    26 Dec 13 18:48:01      1
# 19            1 Apr 2014 06:00:32   9 Sep 2020 19:00:30  22628
# 20           01 Apr 2014 02:56:09  31 Oct 2019 20:17:55  91912

# %%
df.loc[df.local_date == '26 Dec 13 18:48:01', 'local_date'] = '26 Dec 2013 18:48:01'
df.local_date = pd.to_datetime(df.local_date, format = '%d %b %Y %H:%M:%S')
df = df.drop('date_length', axis = 1)

# %%
# Time Zones
df['timezone'] = df.date
df['timezone'] = df.timezone.apply(lambda x: ('+' + x.split('+')[1]) if '+' in x else x)
df['timezone'] = df.timezone.apply(lambda x: ('-' + x.split('-')[1]) if '-' in x else x)
df['timezone'] = df.timezone.apply(lambda x: '+0000' if ('GMT' in x) or ('-0000' in x) else x)
df['timezone'] = df.timezone.apply(lambda x: (x.split('(')[0]) if '(' in x else x)
df['timezone'] = df.timezone.apply(lambda x: 'unspecified' if ':' in x else x)
df['timezone'] = df.timezone.apply(lambda x: 'unspecified' if '-MAR' in x else x)
df['timezone'] = df.timezone.str.strip()
np.sort(df['timezone'].unique()).tolist()
# Out:
# ['+0000',
#  '+0100',
#  '+0200',
#  '+0300',
#  '+0330',
#  '+0400',
#  '+0430',
#  '+0500',
#  '+0530',
#  '+0545',
#  '+0580',
#  '+0600',
#  '+0700',
#  '+0800',
#  '+0900',
#  '+1000',
#  '+1100',
#  '-0300',
#  '-0400',
#  '-0500',
#  '-0600',
#  '-0700',
#  '-0800',
#  'unspecified']

# %%
#Defining a function for EDA
def color_format(df, formatting = None):
    palette = sns.light_palette('seagreen', as_cmap = True)
    df = df.style.background_gradient(cmap = palette).format(formatting, na_rep = '').highlight_null(null_color = 'white')
    return(df)

# %%
color_format(df.groupby('label_type')['timezone'].value_counts(normalize = True).unstack().transpose(), "{:.0%}")
# Out:
# <style  type="text/css" >
# #T_9e0c8_row0_col0,#T_9e0c8_row0_col6{
#             background-color:  #d0e4d8;
#             color:  #000000;
#         }#T_9e0c8_row0_col1,#T_9e0c8_row0_col2,#T_9e0c8_row0_col3,#T_9e0c8_row0_col4,#T_9e0c8_row0_col5,#T_9e0c8_row0_col7,#T_9e0c8_row8_col0,#T_9e0c8_row8_col6{
#             background-color:  #2e8b57;
#             color:  #000000;
#         }#T_9e0c8_row1_col0,#T_9e0c8_row1_col3,#T_9e0c8_row2_col0,#T_9e0c8_row12_col2,#T_9e0c8_row21_col6{
#             background-color:  #e9f1eb;
#             color:  #000000;
#         }#T_9e0c8_row1_col1{
#             background-color:  #e1ede6;
#             color:  #000000;
#         }#T_9e0c8_row1_col2{
#             background-color:  #e5efe9;
#             color:  #000000;
#         }#T_9e0c8_row1_col4,#T_9e0c8_row1_col5,#T_9e0c8_row3_col0,#T_9e0c8_row3_col1,#T_9e0c8_row3_col2,#T_9e0c8_row3_col7,#T_9e0c8_row4_col1,#T_9e0c8_row5_col0,#T_9e0c8_row5_col1,#T_9e0c8_row5_col7,#T_9e0c8_row6_col1,#T_9e0c8_row7_col0,#T_9e0c8_row9_col0,#T_9e0c8_row9_col1,#T_9e0c8_row10_col1,#T_9e0c8_row10_col7,#T_9e0c8_row11_col0,#T_9e0c8_row11_col1,#T_9e0c8_row12_col0,#T_9e0c8_row12_col5,#T_9e0c8_row13_col1,#T_9e0c8_row13_col7,#T_9e0c8_row14_col1,#T_9e0c8_row14_col2,#T_9e0c8_row14_col7,#T_9e0c8_row15_col1,#T_9e0c8_row15_col2,#T_9e0c8_row15_col7,#T_9e0c8_row16_col0,#T_9e0c8_row16_col1,#T_9e0c8_row17_col5,#T_9e0c8_row18_col0,#T_9e0c8_row18_col6,#T_9e0c8_row19_col0,#T_9e0c8_row19_col3,#T_9e0c8_row22_col1,#T_9e0c8_row22_col7{
#             background-color:  #ebf3ed;
#             color:  #000000;
#         }#T_9e0c8_row1_col6,#T_9e0c8_row2_col5,#T_9e0c8_row3_col3,#T_9e0c8_row3_col4,#T_9e0c8_row3_col5,#T_9e0c8_row3_col6,#T_9e0c8_row4_col0,#T_9e0c8_row4_col2,#T_9e0c8_row4_col3,#T_9e0c8_row4_col4,#T_9e0c8_row4_col5,#T_9e0c8_row4_col6,#T_9e0c8_row4_col7,#T_9e0c8_row5_col2,#T_9e0c8_row5_col3,#T_9e0c8_row5_col4,#T_9e0c8_row5_col5,#T_9e0c8_row5_col6,#T_9e0c8_row6_col0,#T_9e0c8_row6_col2,#T_9e0c8_row6_col3,#T_9e0c8_row6_col4,#T_9e0c8_row6_col5,#T_9e0c8_row6_col6,#T_9e0c8_row6_col7,#T_9e0c8_row7_col1,#T_9e0c8_row7_col2,#T_9e0c8_row7_col3,#T_9e0c8_row7_col4,#T_9e0c8_row7_col5,#T_9e0c8_row7_col6,#T_9e0c8_row7_col7,#T_9e0c8_row8_col4,#T_9e0c8_row9_col2,#T_9e0c8_row9_col3,#T_9e0c8_row9_col4,#T_9e0c8_row9_col5,#T_9e0c8_row9_col6,#T_9e0c8_row9_col7,#T_9e0c8_row10_col0,#T_9e0c8_row10_col2,#T_9e0c8_row10_col3,#T_9e0c8_row10_col4,#T_9e0c8_row10_col5,#T_9e0c8_row10_col6,#T_9e0c8_row11_col2,#T_9e0c8_row11_col3,#T_9e0c8_row11_col4,#T_9e0c8_row11_col5,#T_9e0c8_row11_col6,#T_9e0c8_row11_col7,#T_9e0c8_row12_col4,#T_9e0c8_row12_col6,#T_9e0c8_row13_col0,#T_9e0c8_row13_col2,#T_9e0c8_row13_col3,#T_9e0c8_row13_col4,#T_9e0c8_row13_col5,#T_9e0c8_row13_col6,#T_9e0c8_row14_col0,#T_9e0c8_row14_col3,#T_9e0c8_row14_col4,#T_9e0c8_row14_col5,#T_9e0c8_row14_col6,#T_9e0c8_row15_col0,#T_9e0c8_row15_col3,#T_9e0c8_row15_col4,#T_9e0c8_row15_col5,#T_9e0c8_row15_col6,#T_9e0c8_row16_col2,#T_9e0c8_row16_col3,#T_9e0c8_row16_col4,#T_9e0c8_row16_col5,#T_9e0c8_row16_col6,#T_9e0c8_row16_col7,#T_9e0c8_row17_col3,#T_9e0c8_row17_col4,#T_9e0c8_row17_col6,#T_9e0c8_row18_col4,#T_9e0c8_row19_col4,#T_9e0c8_row19_col5,#T_9e0c8_row19_col6,#T_9e0c8_row20_col5,#T_9e0c8_row21_col5,#T_9e0c8_row22_col0,#T_9e0c8_row22_col2,#T_9e0c8_row22_col3,#T_9e0c8_row22_col4,#T_9e0c8_row22_col5,#T_9e0c8_row22_col6{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_9e0c8_row1_col7{
#             background-color:  #e6f0e9;
#             color:  #000000;
#         }#T_9e0c8_row2_col1{
#             background-color:  #ddebe2;
#             color:  #000000;
#         }#T_9e0c8_row2_col2,#T_9e0c8_row17_col7{
#             background-color:  #dfece4;
#             color:  #000000;
#         }#T_9e0c8_row2_col3,#T_9e0c8_row20_col0,#T_9e0c8_row20_col6{
#             background-color:  #deebe3;
#             color:  #000000;
#         }#T_9e0c8_row2_col4,#T_9e0c8_row12_col3,#T_9e0c8_row17_col0,#T_9e0c8_row18_col3,#T_9e0c8_row21_col3{
#             background-color:  #eaf2ed;
#             color:  #000000;
#         }#T_9e0c8_row2_col6{
#             background-color:  #b3d4c1;
#             color:  #000000;
#         }#T_9e0c8_row2_col7,#T_9e0c8_row19_col7{
#             background-color:  #e4eee7;
#             color:  #000000;
#         }#T_9e0c8_row8_col1{
#             background-color:  #3f9465;
#             color:  #000000;
#         }#T_9e0c8_row8_col2{
#             background-color:  #bfdbca;
#             color:  #000000;
#         }#T_9e0c8_row8_col3{
#             background-color:  #dbeae1;
#             color:  #000000;
#         }#T_9e0c8_row8_col5{
#             background-color:  #c9e0d2;
#             color:  #000000;
#         }#T_9e0c8_row8_col7{
#             background-color:  #c2dccd;
#             color:  #000000;
#         }#T_9e0c8_row12_col1,#T_9e0c8_row18_col5{
#             background-color:  #e8f1eb;
#             color:  #000000;
#         }#T_9e0c8_row12_col7,#T_9e0c8_row21_col0{
#             background-color:  #e9f2ec;
#             color:  #000000;
#         }#T_9e0c8_row17_col1,#T_9e0c8_row21_col1,#T_9e0c8_row21_col4{
#             background-color:  #e2eee6;
#             color:  #000000;
#         }#T_9e0c8_row17_col2,#T_9e0c8_row20_col3{
#             background-color:  #e4efe8;
#             color:  #000000;
#         }#T_9e0c8_row18_col1,#T_9e0c8_row20_col2{
#             background-color:  #e0ece4;
#             color:  #000000;
#         }#T_9e0c8_row18_col2{
#             background-color:  #dae9e0;
#             color:  #000000;
#         }#T_9e0c8_row18_col7{
#             background-color:  #dceae1;
#             color:  #000000;
#         }#T_9e0c8_row19_col1{
#             background-color:  #e3eee7;
#             color:  #000000;
#         }#T_9e0c8_row19_col2,#T_9e0c8_row20_col1{
#             background-color:  #d5e6dc;
#             color:  #000000;
#         }#T_9e0c8_row20_col4{
#             background-color:  #d3e5da;
#             color:  #000000;
#         }#T_9e0c8_row20_col7{
#             background-color:  #bfdaca;
#             color:  #000000;
#         }#T_9e0c8_row21_col2{
#             background-color:  #e7f1ea;
#             color:  #000000;
#         }#T_9e0c8_row21_col7{
#             background-color:  #d7e8dd;
#             color:  #000000;
#         }</style><table id="T_9e0c8_" ><thead>    <tr>        <th class="index_name level0" >label_type</th>        <th class="col_heading level0 col0" >Forums</th>        <th class="col_heading level0 col1" >Personal</th>        <th class="col_heading level0 col2" >Promotions</th>        <th class="col_heading level0 col3" >Purchases</th>        <th class="col_heading level0 col4" >Social</th>        <th class="col_heading level0 col5" >Spam</th>        <th class="col_heading level0 col6" >Travel</th>        <th class="col_heading level0 col7" >Updates</th>    </tr>    <tr>        <th class="index_name level0" >timezone</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e0c8_level0_row0" class="row_heading level0 row0" >+0000</th>
#                         <td id="T_9e0c8_row0_col0" class="data row0 col0" >11%</td>
#                         <td id="T_9e0c8_row0_col1" class="data row0 col1" >42%</td>
#                         <td id="T_9e0c8_row0_col2" class="data row0 col2" >60%</td>
#                         <td id="T_9e0c8_row0_col3" class="data row0 col3" >80%</td>
#                         <td id="T_9e0c8_row0_col4" class="data row0 col4" >84%</td>
#                         <td id="T_9e0c8_row0_col5" class="data row0 col5" >81%</td>
#                         <td id="T_9e0c8_row0_col6" class="data row0 col6" >10%</td>
#                         <td id="T_9e0c8_row0_col7" class="data row0 col7" >55%</td>
#             </tr>
#             <tr>
#                         <th id="T_9e0c8_level0_row1" class="row_heading level0

# %%
df['day'] = df.local_date.dt.day
df['weekday'] = df.local_date.dt.weekday
df['weekend'] = np.where(df.local_date.dt.weekday.isin([5,6]), 1, 0)
df['month'] = df.local_date.dt.month
df['hour'] = df.local_date.dt.hour
df['minutes'] = df.local_date.dt.minute
df['seconds'] = df.local_date.dt.second

color_format(df.groupby('label_type')['day'].value_counts(normalize = True).unstack().transpose(), "{:.0%}")
# Out:
# <style  type="text/css" >
# #T_365e5_row0_col0{
#             background-color:  #48996c;
#             color:  #000000;
#         }#T_365e5_row0_col1,#T_365e5_row9_col3,#T_365e5_row26_col1{
#             background-color:  #9dc8af;
#             color:  #000000;
#         }#T_365e5_row0_col2{
#             background-color:  #93c2a7;
#             color:  #000000;
#         }#T_365e5_row0_col3,#T_365e5_row11_col3{
#             background-color:  #66a983;
#             color:  #000000;
#         }#T_365e5_row0_col4,#T_365e5_row8_col1,#T_365e5_row25_col4{
#             background-color:  #84ba9b;
#             color:  #000000;
#         }#T_365e5_row0_col5,#T_365e5_row2_col6,#T_365e5_row9_col5,#T_365e5_row11_col5,#T_365e5_row14_col5,#T_365e5_row15_col6,#T_365e5_row18_col6,#T_365e5_row24_col6,#T_365e5_row28_col5{
#             background-color:  #d3e6da;
#             color:  #000000;
#         }#T_365e5_row0_col6,#T_365e5_row2_col1,#T_365e5_row10_col6{
#             background-color:  #98c5ab;
#             color:  #000000;
#         }#T_365e5_row0_col7{
#             background-color:  #97c5ab;
#             color:  #000000;
#         }#T_365e5_row1_col0,#T_365e5_row26_col2{
#             background-color:  #62a780;
#             color:  #000000;
#         }#T_365e5_row1_col1,#T_365e5_row18_col0{
#             background-color:  #a1cab2;
#             color:  #000000;
#         }#T_365e5_row1_col2,#T_365e5_row7_col1{
#             background-color:  #8bbea1;
#             color:  #000000;
#         }#T_365e5_row1_col3,#T_365e5_row12_col3,#T_365e5_row13_col3,#T_365e5_row23_col4,#T_365e5_row28_col3,#T_365e5_row29_col3{
#             background-color:  #5aa37a;
#             color:  #000000;
#         }#T_365e5_row1_col4,#T_365e5_row5_col1{
#             background-color:  #86bb9d;
#             color:  #000000;
#         }#T_365e5_row1_col5,#T_365e5_row3_col5,#T_365e5_row7_col6,#T_365e5_row8_col6,#T_365e5_row17_col5,#T_365e5_row22_col6,#T_365e5_row25_col6,#T_365e5_row26_col6,#T_365e5_row28_col7,#T_365e5_row29_col5{
#             background-color:  #bcd9c8;
#             color:  #000000;
#         }#T_365e5_row1_col6,#T_365e5_row10_col5,#T_365e5_row30_col5{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_365e5_row1_col7,#T_365e5_row24_col0{
#             background-color:  #9ec8b0;
#             color:  #000000;
#         }#T_365e5_row2_col0{
#             background-color:  #539f74;
#             color:  #000000;
#         }#T_365e5_row2_col2{
#             background-color:  #b9d7c5;
#             color:  #000000;
#         }#T_365e5_row2_col3,#T_365e5_row27_col3{
#             background-color:  #399160;
#             color:  #000000;
#         }#T_365e5_row2_col4,#T_365e5_row22_col4{
#             background-color:  #7db695;
#             color:  #000000;
#         }#T_365e5_row2_col5,#T_365e5_row4_col5,#T_365e5_row6_col6,#T_365e5_row7_col5,#T_365e5_row19_col3,#T_365e5_row20_col6,#T_365e5_row21_col6,#T_365e5_row22_col0,#T_365e5_row23_col6,#T_365e5_row27_col6,#T_365e5_row28_col6,#T_365e5_row30_col1,#T_365e5_row30_col2,#T_365e5_row30_col4,#T_365e5_row30_col6,#T_365e5_row30_col7{
#             background-color:  #ebf3ed;
#             color:  #000000;
#         }#T_365e5_row2_col7,#T_365e5_row26_col0,#T_365e5_row27_col0,#T_365e5_row27_col1{
#             background-color:  #a3cbb4;
#             color:  #000000;
#         }#T_365e5_row3_col0{
#             background-color:  #429667;
#             color:  #000000;
#         }#T_365e5_row3_col1,#T_365e5_row9_col1{
#             background-color:  #99c6ac;
#             color:  #000000;
#         }#T_365e5_row3_col2,#T_365e5_row8_col7{
#             background-color:  #94c3a8;
#             color:  #000000;
#         }#T_365e5_row3_col3,#T_365e5_row7_col3,#T_365e5_row16_col3,#T_365e5_row26_col3{
#             background-color:  #4f9d72;
#             color:  #000000;
#         }#T_365e5_row3_col4{
#             background-color:  #9bc7ae;
#             color:  #000000;
#         }#T_365e5_row3_col6,#T_365e5_row9_col6,#T_365e5_row14_col6{
#             background-color:  #c7dfd1;
#             color:  #000000;
#         }#T_365e5_row3_col7,#T_365e5_row13_col7,#T_365e5_row24_col1,#T_365e5_row24_col7{
#             background-color:  #a9ceb9;
#             color:  #000000;
#         }#T_365e5_row4_col0{
#             background-color:  #55a076;
#             color:  #000000;
#         }#T_365e5_row4_col1,#T_365e5_row10_col2,#T_365e5_row24_col4{
#             background-color:  #8fc0a4;
#             color:  #000000;
#         }#T_365e5_row4_col2{
#             background-color:  #60a77f;
#             color:  #000000;
#         }#T_365e5_row4_col3,#T_365e5_row23_col3{
#             background-color:  #87bc9e;
#             color:  #000000;
#         }#T_365e5_row4_col4,#T_365e5_row18_col4{
#             background-color:  #68ab85;
#             color:  #000000;
#         }#T_365e5_row4_col6,#T_365e5_row5_col6{
#             background-color:  #dfece4;
#             color:  #000000;
#         }#T_365e5_row4_col7,#T_365e5_row10_col7,#T_365e5_row16_col0,#T_365e5_row29_col4{
#             background-color:  #a0cab2;
#             color:  #000000;
#         }#T_365e5_row5_col0,#T_365e5_row6_col1,#T_365e5_row6_col7,#T_365e5_row9_col4,#T_365e5_row16_col2,#T_365e5_row16_col6,#T_365e5_row18_col3,#T_365e5_row19_col2,#T_365e5_row19_col5,#T_365e5_row27_col2{
#             background-color:  #2e8b57;
#             color:  #000000;
#         }#T_365e5_row5_col2,#T_365e5_row15_col7{
#             background-color:  #abd0bb;
#             color:  #000000;
#         }#T_365e5_row5_col3,#T_365e5_row6_col3{
#             background-color:  #92c2a7;
#             color:  #000000;
#         }#T_365e5_row5_col4,#T_365e5_row6_col5,#T_365e5_row13_col5,#T_365e5_row14_col1,#T_365e5_row20_col5,#T_365e5_row21_col5,#T_365e5_row25_col5{
#             background-color:  #a4ccb5;
#             color:  #000000;
#         }#T_365e5_row5_col5,#T_365e5_row24_col5{
#             background-color:  #8cbfa2;
#             color:  #000000;
#         }#T_365e5_row5_col7{
#             background-color:  #acd0bb;
#             color:  #000000;
#         }#T_365e5_row6_col0,#T_365e5_row9_col2{
#             background-color:  #3f9465;
#             color:  #000000;
#         }#T_365e5_row6_col2,#T_365e5_row8_col2,#T_365e5_row28_col4{
#             background-color:  #59a379;
#             color:  #000000;
#         }#T_365e5_row6_col4,#T_365e5_row12_col4{
#             background-color:  #4a9a6d;
#             color:  #000000;
#         }#T_365e5_row7_col0{
#             background-color:  #328d5b;
#             color:  #000000;
#         }#T_365e5_row7_col2{
#             background-color:  #73b18e;
#             color:  #000000;
#         }#T_365e5_row7_col4{
#             background-color:  #4c9b6f;
#             color:  #000000;
#         }#T_365e5_row7_col7,#T_365e5_row15_col1{
#             background-color:  #a2cab3;
#             color:  #000000;
#         }#T_365e5_row8_col0{
#             background-color:  #439667;
#             color:  #000000;
#         }#T_365e5_row8_col3,#T_365e5_row22_col3{
#             background-color:  #b3d4c1;
#             color:  #000000;
#         }#T_365e5_row8_col4{
#             background-color:  #7ab594;
#             color:  #000000;
#         }#T_365e5_row8_col5,#T_365e5_row15_col5,#T_365e5_row16_col5,#T_365e5_row26_col5,#T_365e5_row27_col5,#T_365e5_row29_col6{
#             background-color:  #74b28f;
#             color:  #000000;
#         }#T_365e5_row9_col0{
#             background-color:  #38905f;
#             color:  #000000;
#         }#T_365e5_row9_col7{
#             background-color:  #add1bc;
#             color:  #000000;
#         }#T_365e5_row10_col0{
#             background-color:  #81b899;
#             color:  #000000;
#         }#T_365e5_row10_col1{
#             background-color:  #82b99a;
#             color:  #000000;
#         }#T_365e5_row10_col3{
#             background-color:  #71b08c;
#             color:  #000000;
#         }#T_365e5_row10_col4,#T_365e5_row11_col6,#T_365e5_row12_col2,#T_365e5_row12_col5,#T_365e5_row13_col2,#T_365e5_row18_col5,#T_365e5_row23_col2,#T_365e5_row23_col5{
#             background-color:  #5da57c;
#             c

# %%
color_format(df.groupby('label_type')['weekday'].value_counts(normalize = True).unstack().transpose(), "{:.0%}")
# Out:
# <style  type="text/css" >
# #T_aea10_row0_col0{
#             background-color:  #499a6c;
#             color:  #000000;
#         }#T_aea10_row0_col1{
#             background-color:  #4c9c6f;
#             color:  #000000;
#         }#T_aea10_row0_col2{
#             background-color:  #8abda0;
#             color:  #000000;
#         }#T_aea10_row0_col3,#T_aea10_row0_col4,#T_aea10_row0_col6,#T_aea10_row1_col0,#T_aea10_row1_col5,#T_aea10_row1_col7,#T_aea10_row3_col2,#T_aea10_row4_col1{
#             background-color:  #2e8b57;
#             color:  #000000;
#         }#T_aea10_row0_col5{
#             background-color:  #7ab493;
#             color:  #000000;
#         }#T_aea10_row0_col7{
#             background-color:  #82b99a;
#             color:  #000000;
#         }#T_aea10_row1_col1{
#             background-color:  #4b9b6e;
#             color:  #000000;
#         }#T_aea10_row1_col2{
#             background-color:  #459869;
#             color:  #000000;
#         }#T_aea10_row1_col3,#T_aea10_row3_col5,#T_aea10_row5_col6,#T_aea10_row6_col0,#T_aea10_row6_col1,#T_aea10_row6_col2,#T_aea10_row6_col4,#T_aea10_row6_col7{
#             background-color:  #ebf3ed;
#             color:  #000000;
#         }#T_aea10_row1_col4{
#             background-color:  #5ea57d;
#             color:  #000000;
#         }#T_aea10_row1_col6{
#             background-color:  #358f5c;
#             color:  #000000;
#         }#T_aea10_row2_col0{
#             background-color:  #46986a;
#             color:  #000000;
#         }#T_aea10_row2_col1{
#             background-color:  #5da57c;
#             color:  #000000;
#         }#T_aea10_row2_col2{
#             background-color:  #55a076;
#             color:  #000000;
#         }#T_aea10_row2_col3{
#             background-color:  #bcd9c8;
#             color:  #000000;
#         }#T_aea10_row2_col4{
#             background-color:  #4a9a6d;
#             color:  #000000;
#         }#T_aea10_row2_col5{
#             background-color:  #b3d4c0;
#             color:  #000000;
#         }#T_aea10_row2_col6{
#             background-color:  #acd0bb;
#             color:  #000000;
#         }#T_aea10_row2_col7{
#             background-color:  #86bb9d;
#             color:  #000000;
#         }#T_aea10_row3_col0{
#             background-color:  #399160;
#             color:  #000000;
#         }#T_aea10_row3_col1{
#             background-color:  #47996b;
#             color:  #000000;
#         }#T_aea10_row3_col3{
#             background-color:  #dbeae1;
#             color:  #000000;
#         }#T_aea10_row3_col4{
#             background-color:  #8fc0a4;
#             color:  #000000;
#         }#T_aea10_row3_col6{
#             background-color:  #b3d4c1;
#             color:  #000000;
#         }#T_aea10_row3_col7{
#             background-color:  #67aa84;
#             color:  #000000;
#         }#T_aea10_row4_col0{
#             background-color:  #539f74;
#             color:  #000000;
#         }#T_aea10_row4_col2{
#             background-color:  #409565;
#             color:  #000000;
#         }#T_aea10_row4_col3{
#             background-color:  #7db695;
#             color:  #000000;
#         }#T_aea10_row4_col4,#T_aea10_row5_col5{
#             background-color:  #a9ceb9;
#             color:  #000000;
#         }#T_aea10_row4_col5{
#             background-color:  #66aa84;
#             color:  #000000;
#         }#T_aea10_row4_col6{
#             background-color:  #519e73;
#             color:  #000000;
#         }#T_aea10_row4_col7{
#             background-color:  #5aa37a;
#             color:  #000000;
#         }#T_aea10_row5_col0{
#             background-color:  #deece3;
#             color:  #000000;
#         }#T_aea10_row5_col1{
#             background-color:  #bfdaca;
#             color:  #000000;
#         }#T_aea10_row5_col2{
#             background-color:  #c3ddcd;
#             color:  #000000;
#         }#T_aea10_row5_col3{
#             background-color:  #9cc8af;
#             color:  #000000;
#         }#T_aea10_row5_col4{
#             background-color:  #d9e9df;
#             color:  #000000;
#         }#T_aea10_row5_col7{
#             background-color:  #96c4a9;
#             color:  #000000;
#         }#T_aea10_row6_col3{
#             background-color:  #b4d5c2;
#             color:  #000000;
#         }#T_aea10_row6_col5{
#             background-color:  #d8e8de;
#             color:  #000000;
#         }#T_aea10_row6_col6{
#             background-color:  #bad8c6;
#             color:  #000000;
#         }</style><table id="T_aea10_" ><thead>    <tr>        <th class="index_name level0" >label_type</th>        <th class="col_heading level0 col0" >Forums</th>        <th class="col_heading level0 col1" >Personal</th>        <th class="col_heading level0 col2" >Promotions</th>        <th class="col_heading level0 col3" >Purchases</th>        <th class="col_heading level0 col4" >Social</th>        <th class="col_heading level0 col5" >Spam</th>        <th class="col_heading level0 col6" >Travel</th>        <th class="col_heading level0 col7" >Updates</th>    </tr>    <tr>        <th class="index_name level0" >weekday</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aea10_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aea10_row0_col0" class="data row0 col0" >17%</td>
#                         <td id="T_aea10_row0_col1" class="data row0 col1" >16%</td>
#                         <td id="T_aea10_row0_col2" class="data row0 col2" >13%</td>
#                         <td id="T_aea10_row0_col3" class="data row0 col3" >18%</td>
#                         <td id="T_aea10_row0_col4" class="data row0 col4" >18%</td>
#                         <td id="T_aea10_row0_col5" class="data row0 col5" >16%</td>
#                         <td id="T_aea10_row0_col6" class="data row0 col6" >23%</td>
#                         <td id="T_aea10_row0_col7" class="data row0 col7" >14%</td>
#             </tr>
#             <tr>
#                         <th id="T_aea10_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_aea10_row1_col0" class="data row1 col0" >19%</td>
#                         <td id="T_aea10_row1_col1" class="data row1 col1" >16%</td>
#                         <td id="T_aea10_row1_col2" class="data row1 col2" >17%</td>
#                         <td id="T_aea10_row1_col3" class="data row1 col3" >12%</td>
#                         <td id="T_aea10_row1_col4" class="data row1 col4" >16%</td>
#                         <td id="T_aea10_row1_col5" class="data row1 col5" >22%</td>
#                         <td id="T_aea10_row1_col6" class="data row1 col6" >23%</td>
#                         <td id="T_aea10_row1_col7" class="data row1 col7" >19%</td>
#             </tr>
#             <tr>
#                         <th id="T_aea10_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_aea10_row2_col0" class="data row2 col0" >17%</td>
#                         <td id="T_aea10_row2_col1" class="data row2 col1" >15%</td>
#                         <td id="T_aea10_row2_col2" class="data row2 col2" >16%</td>
#                         <td id="T_aea10_row2_col3" class="data row2 col3" >13%</td>
#                         <td id="T_aea10_row2_col4" class="data row2 col4" >17%</td>
#                         <td id="T_aea10_row2_col5" class="data row2 col5" >12%</td>
#                         <td id="T_aea10_row2_col6" class="data row2 col6" >11%</td>
#                         <td id="T_aea10_row2_col7" class="data row2 col7" >14%</td>
#             </tr>
#             <tr>
#                         <th id="T_aea10_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_aea10_row3_col0" class="data row3 col0" >18%</td>
#                         <td id="T_aea10_row3_col1" class="data row3 col1" >16%</td>
#                         <td id="T_aea10_row3_col2" class="data row3 col2" >18%</td>

# %%
color_format(df.groupby('label_type')['weekend'].value_counts(normalize = True).unstack().transpose(), "{:.0%}")
# Out:
# <style  type="text/css" >
# #T_1ecb9_row0_col0,#T_1ecb9_row0_col1,#T_1ecb9_row0_col2,#T_1ecb9_row0_col3,#T_1ecb9_row0_col4,#T_1ecb9_row0_col5,#T_1ecb9_row0_col6,#T_1ecb9_row0_col7{
#             background-color:  #2e8b57;
#             color:  #000000;
#         }#T_1ecb9_row1_col0,#T_1ecb9_row1_col1,#T_1ecb9_row1_col2,#T_1ecb9_row1_col3,#T_1ecb9_row1_col4,#T_1ecb9_row1_col5,#T_1ecb9_row1_col6,#T_1ecb9_row1_col7{
#             background-color:  #ebf3ed;
#             color:  #000000;
#         }</style><table id="T_1ecb9_" ><thead>    <tr>        <th class="index_name level0" >label_type</th>        <th class="col_heading level0 col0" >Forums</th>        <th class="col_heading level0 col1" >Personal</th>        <th class="col_heading level0 col2" >Promotions</th>        <th class="col_heading level0 col3" >Purchases</th>        <th class="col_heading level0 col4" >Social</th>        <th class="col_heading level0 col5" >Spam</th>        <th class="col_heading level0 col6" >Travel</th>        <th class="col_heading level0 col7" >Updates</th>    </tr>    <tr>        <th class="index_name level0" >weekend</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ecb9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1ecb9_row0_col0" class="data row0 col0" >88%</td>
#                         <td id="T_1ecb9_row0_col1" class="data row0 col1" >80%</td>
#                         <td id="T_1ecb9_row0_col2" class="data row0 col2" >81%</td>
#                         <td id="T_1ecb9_row0_col3" class="data row0 col3" >72%</td>
#                         <td id="T_1ecb9_row0_col4" class="data row0 col4" >79%</td>
#                         <td id="T_1ecb9_row0_col5" class="data row0 col5" >77%</td>
#                         <td id="T_1ecb9_row0_col6" class="data row0 col6" >87%</td>
#                         <td id="T_1ecb9_row0_col7" class="data row0 col7" >78%</td>
#             </tr>
#             <tr>
#                         <th id="T_1ecb9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1ecb9_row1_col0" class="data row1 col0" >12%</td>
#                         <td id="T_1ecb9_row1_col1" class="data row1 col1" >20%</td>
#                         <td id="T_1ecb9_row1_col2" class="data row1 col2" >19%</td>
#                         <td id="T_1ecb9_row1_col3" class="data row1 col3" >28%</td>
#                         <td id="T_1ecb9_row1_col4" class="data row1 col4" >21%</td>
#                         <td id="T_1ecb9_row1_col5" class="data row1 col5" >23%</td>
#                         <td id="T_1ecb9_row1_col6" class="data row1 col6" >13%</td>
#                         <td id="T_1ecb9_row1_col7" class="data row1 col7" >22%</td>
#             </tr>
#     </tbody></table>

# %%
color_format(df.groupby('label_type')['hour'].value_counts(normalize = True).unstack().transpose(), "{:.0%}")
# Out:
# <style  type="text/css" >
# #T_8d159_row0_col0{
#             background-color:  #d9e9df;
#             color:  #000000;
#         }#T_8d159_row0_col1,#T_8d159_row4_col2,#T_8d159_row20_col0,#T_8d159_row23_col6{
#             background-color:  #afd2bd;
#             color:  #000000;
#         }#T_8d159_row0_col2,#T_8d159_row5_col5,#T_8d159_row6_col7,#T_8d159_row8_col4,#T_8d159_row10_col6,#T_8d159_row15_col0,#T_8d159_row15_col1,#T_8d159_row16_col3{
#             background-color:  #2e8b57;
#             color:  #000000;
#         }#T_8d159_row0_col3,#T_8d159_row2_col0,#T_8d159_row2_col1,#T_8d159_row7_col6,#T_8d159_row21_col5,#T_8d159_row21_col7,#T_8d159_row23_col2,#T_8d159_row23_col4,#T_8d159_row23_col5,#T_8d159_row23_col7{
#             background-color:  #ebf3ed;
#             color:  #000000;
#         }#T_8d159_row0_col4,#T_8d159_row6_col0{
#             background-color:  #dfece4;
#             color:  #000000;
#         }#T_8d159_row0_col5,#T_8d159_row1_col5,#T_8d159_row7_col0{
#             background-color:  #d8e8de;
#             color:  #000000;
#         }#T_8d159_row0_col6,#T_8d159_row4_col6,#T_8d159_row16_col5,#T_8d159_row22_col5{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_8d159_row0_col7{
#             background-color:  #cde2d5;
#             color:  #000000;
#         }#T_8d159_row1_col0,#T_8d159_row22_col7{
#             background-color:  #e7f1ea;
#             color:  #000000;
#         }#T_8d159_row1_col1{
#             background-color:  #cae0d3;
#             color:  #000000;
#         }#T_8d159_row1_col2,#T_8d159_row14_col5{
#             background-color:  #9fc9b1;
#             color:  #000000;
#         }#T_8d159_row1_col3,#T_8d159_row2_col3,#T_8d159_row3_col3,#T_8d159_row19_col3{
#             background-color:  #e4efe8;
#             color:  #000000;
#         }#T_8d159_row1_col4{
#             background-color:  #bedac9;
#             color:  #000000;
#         }#T_8d159_row1_col6{
#             background-color:  #c9e0d2;
#             color:  #000000;
#         }#T_8d159_row1_col7{
#             background-color:  #cee3d6;
#             color:  #000000;
#         }#T_8d159_row2_col2,#T_8d159_row22_col0,#T_8d159_row23_col0{
#             background-color:  #c0dbcb;
#             color:  #000000;
#         }#T_8d159_row2_col4,#T_8d159_row2_col7{
#             background-color:  #c1dccc;
#             color:  #000000;
#         }#T_8d159_row2_col5,#T_8d159_row3_col5,#T_8d159_row17_col5,#T_8d159_row18_col5,#T_8d159_row20_col5{
#             background-color:  #e2eee6;
#             color:  #000000;
#         }#T_8d159_row2_col6,#T_8d159_row12_col6,#T_8d159_row13_col6,#T_8d159_row19_col6,#T_8d159_row20_col6{
#             background-color:  #dae9e0;
#             color:  #000000;
#         }#T_8d159_row3_col0{
#             background-color:  #e6f0e9;
#             color:  #000000;
#         }#T_8d159_row3_col1{
#             background-color:  #d4e6db;
#             color:  #000000;
#         }#T_8d159_row3_col2{
#             background-color:  #8ec0a4;
#             color:  #000000;
#         }#T_8d159_row3_col4{
#             background-color:  #c4ddcf;
#             color:  #000000;
#         }#T_8d159_row3_col6,#T_8d159_row6_col6,#T_8d159_row9_col6{
#             background-color:  #d2e5d9;
#             color:  #000000;
#         }#T_8d159_row3_col7,#T_8d159_row11_col7{
#             background-color:  #7ab594;
#             color:  #000000;
#         }#T_8d159_row4_col0,#T_8d159_row22_col2,#T_8d159_row23_col1{
#             background-color:  #deece3;
#             color:  #000000;
#         }#T_8d159_row4_col1,#T_8d159_row21_col1{
#             background-color:  #c8dfd2;
#             color:  #000000;
#         }#T_8d159_row4_col3,#T_8d159_row23_col3{
#             background-color:  #ddebe2;
#             color:  #000000;
#         }#T_8d159_row4_col4,#T_8d159_row15_col4,#T_8d159_row22_col3{
#             background-color:  #bfdbca;
#             color:  #000000;
#         }#T_8d159_row4_col5,#T_8d159_row7_col5,#T_8d159_row12_col5,#T_8d159_row22_col1{
#             background-color:  #c5decf;
#             color:  #000000;
#         }#T_8d159_row4_col7{
#             background-color:  #6aac87;
#             color:  #000000;
#         }#T_8d159_row5_col0{
#             background-color:  #e1ede6;
#             color:  #000000;
#         }#T_8d159_row5_col1{
#             background-color:  #d6e7dd;
#             color:  #000000;
#         }#T_8d159_row5_col2{
#             background-color:  #96c4a9;
#             color:  #000000;
#         }#T_8d159_row5_col3{
#             background-color:  #a2cbb3;
#             color:  #000000;
#         }#T_8d159_row5_col4,#T_8d159_row15_col5,#T_8d159_row17_col4,#T_8d159_row19_col5{
#             background-color:  #bcd9c8;
#             color:  #000000;
#         }#T_8d159_row5_col6,#T_8d159_row17_col6,#T_8d159_row18_col6{
#             background-color:  #e3eee7;
#             color:  #000000;
#         }#T_8d159_row5_col7{
#             background-color:  #6faf8b;
#             color:  #000000;
#         }#T_8d159_row6_col1,#T_8d159_row8_col6{
#             background-color:  #b8d7c5;
#             color:  #000000;
#         }#T_8d159_row6_col2{
#             background-color:  #82b99a;
#             color:  #000000;
#         }#T_8d159_row6_col3,#T_8d159_row18_col7{
#             background-color:  #aacfb9;
#             color:  #000000;
#         }#T_8d159_row6_col4{
#             background-color:  #b2d3c0;
#             color:  #000000;
#         }#T_8d159_row6_col5,#T_8d159_row10_col5,#T_8d159_row12_col3,#T_8d159_row17_col3{
#             background-color:  #8dbfa2;
#             color:  #000000;
#         }#T_8d159_row7_col1,#T_8d159_row20_col3{
#             background-color:  #b1d3bf;
#             color:  #000000;
#         }#T_8d159_row7_col2{
#             background-color:  #71b08c;
#             color:  #000000;
#         }#T_8d159_row7_col3{
#             background-color:  #529f74;
#             color:  #000000;
#         }#T_8d159_row7_col4{
#             background-color:  #9bc7ae;
#             color:  #000000;
#         }#T_8d159_row7_col7,#T_8d159_row8_col7{
#             background-color:  #66aa84;
#             color:  #000000;
#         }#T_8d159_row8_col0{
#             background-color:  #acd0bb;
#             color:  #000000;
#         }#T_8d159_row8_col1{
#             background-color:  #91c1a5;
#             color:  #000000;
#         }#T_8d159_row8_col2,#T_8d159_row9_col3{
#             background-color:  #68ab85;
#             color:  #000000;
#         }#T_8d159_row8_col3,#T_8d159_row18_col3{
#             background-color:  #5aa37a;
#             color:  #000000;
#         }#T_8d159_row8_col5{
#             background-color:  #cfe3d7;
#             color:  #000000;
#         }#T_8d159_row9_col0{
#             background-color:  #5ea57d;
#             color:  #000000;
#         }#T_8d159_row9_col1,#T_8d159_row10_col3,#T_8d159_row15_col3{
#             background-color:  #60a77f;
#             color:  #000000;
#         }#T_8d159_row9_col2{
#             background-color:  #6cad88;
#             color:  #000000;
#         }#T_8d159_row9_col4{
#             background-color:  #4b9b6e;
#             color:  #000000;
#         }#T_8d159_row9_col5,#T_8d159_row14_col7{
#             background-color:  #7ab493;
#             color:  #000000;
#         }#T_8d159_row9_col7,#T_8d159_row11_col0{
#             background-color:  #4c9b6f;
#             color:  #000000;
#         }#T_8d159_row10_col0{
#             background-color:  #5ba47b;
#             color:  #000000;
#         }#T_8d159_row10_col1,#T_8d159_row16_col1{
#             background-color:  #4e9c70;
#             color:  #000000;
#         }#T_8d159_row10_col2,#T_8d159_row12_col7,#T_8d159_row13_col2,#T_8d159_row17_col1{
#             background-color:  #69ab86;
#             color:  #000000;
#         }#T_8d159_row10_col4,#T_8d159_row18_col1{
#             background-color:  #90c1a5;
#             color:  #000000;
#         }#T_8d159_row10_col7{
#             background-color:  #5ca47c;
#             color:  #000000;
#         }#T_8d159_row11_col1,#T_8d159_row13_col1{
#             background-color:  #539f74;
#             color:  #000000;
#         }#T_8d159_row11_col2{
#             backgrou

# %%
df['promotion_hour'] = np.where(df.hour.isin([0]), 1, 0)
df['spam_hour'] = np.where(df.hour.isin([5]), 1, 0)
df['travel_hour'] = np.where(df.hour.isin([10]), 1, 0)

# %%
color_format(df.groupby('label_type')['month'].value_counts(normalize = True).unstack().transpose(), "{:.0%}")
# Out:
# <style  type="text/css" >
# #T_459ea_row0_col0,#T_459ea_row7_col3{
#             background-color:  #7db696;
#             color:  #000000;
#         }#T_459ea_row0_col1,#T_459ea_row0_col3,#T_459ea_row8_col3{
#             background-color:  #bad8c6;
#             color:  #000000;
#         }#T_459ea_row0_col2{
#             background-color:  #bfdbca;
#             color:  #000000;
#         }#T_459ea_row0_col4,#T_459ea_row1_col7{
#             background-color:  #d6e7dd;
#             color:  #000000;
#         }#T_459ea_row0_col5,#T_459ea_row1_col5,#T_459ea_row2_col5,#T_459ea_row3_col5,#T_459ea_row4_col5,#T_459ea_row5_col5,#T_459ea_row6_col5,#T_459ea_row7_col5,#T_459ea_row10_col5,#T_459ea_row11_col5{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_459ea_row0_col6,#T_459ea_row1_col6,#T_459ea_row10_col6,#T_459ea_row10_col7{
#             background-color:  #dceae1;
#             color:  #000000;
#         }#T_459ea_row0_col7{
#             background-color:  #bfdaca;
#             color:  #000000;
#         }#T_459ea_row1_col0{
#             background-color:  #a5ccb6;
#             color:  #000000;
#         }#T_459ea_row1_col1{
#             background-color:  #e1ede6;
#             color:  #000000;
#         }#T_459ea_row1_col2{
#             background-color:  #8dbfa2;
#             color:  #000000;
#         }#T_459ea_row1_col3,#T_459ea_row2_col6,#T_459ea_row5_col0,#T_459ea_row8_col5,#T_459ea_row10_col2,#T_459ea_row10_col4,#T_459ea_row11_col1,#T_459ea_row11_col2,#T_459ea_row11_col7{
#             background-color:  #ebf3ed;
#             color:  #000000;
#         }#T_459ea_row1_col4{
#             background-color:  #9ec8b0;
#             color:  #000000;
#         }#T_459ea_row2_col0{
#             background-color:  #a4ccb5;
#             color:  #000000;
#         }#T_459ea_row2_col1{
#             background-color:  #95c3a9;
#             color:  #000000;
#         }#T_459ea_row2_col2{
#             background-color:  #55a176;
#             color:  #000000;
#         }#T_459ea_row2_col3{
#             background-color:  #6eae8a;
#             color:  #000000;
#         }#T_459ea_row2_col4{
#             background-color:  #acd0bb;
#             color:  #000000;
#         }#T_459ea_row2_col7{
#             background-color:  #add1bc;
#             color:  #000000;
#         }#T_459ea_row3_col0{
#             background-color:  #b0d2be;
#             color:  #000000;
#         }#T_459ea_row3_col1{
#             background-color:  #55a076;
#             color:  #000000;
#         }#T_459ea_row3_col2{
#             background-color:  #91c1a6;
#             color:  #000000;
#         }#T_459ea_row3_col3,#T_459ea_row4_col3,#T_459ea_row5_col1{
#             background-color:  #94c3a8;
#             color:  #000000;
#         }#T_459ea_row3_col4{
#             background-color:  #9cc7ae;
#             color:  #000000;
#         }#T_459ea_row3_col6{
#             background-color:  #91c1a5;
#             color:  #000000;
#         }#T_459ea_row3_col7{
#             background-color:  #79b492;
#             color:  #000000;
#         }#T_459ea_row4_col0{
#             background-color:  #e9f1eb;
#             color:  #000000;
#         }#T_459ea_row4_col1{
#             background-color:  #c7dfd1;
#             color:  #000000;
#         }#T_459ea_row4_col2{
#             background-color:  #66a983;
#             color:  #000000;
#         }#T_459ea_row4_col4{
#             background-color:  #76b290;
#             color:  #000000;
#         }#T_459ea_row4_col6{
#             background-color:  #6aac87;
#             color:  #000000;
#         }#T_459ea_row4_col7{
#             background-color:  #d9e9df;
#             color:  #000000;
#         }#T_459ea_row5_col2{
#             background-color:  #7bb594;
#             color:  #000000;
#         }#T_459ea_row5_col3,#T_459ea_row6_col1,#T_459ea_row6_col6,#T_459ea_row6_col7,#T_459ea_row7_col0,#T_459ea_row8_col2,#T_459ea_row8_col4,#T_459ea_row9_col5{
#             background-color:  #2e8b57;
#             color:  #000000;
#         }#T_459ea_row5_col4{
#             background-color:  #69ab86;
#             color:  #000000;
#         }#T_459ea_row5_col6{
#             background-color:  #5ba47b;
#             color:  #000000;
#         }#T_459ea_row5_col7{
#             background-color:  #c1dbcc;
#             color:  #000000;
#         }#T_459ea_row6_col0{
#             background-color:  #c3ddcd;
#             color:  #000000;
#         }#T_459ea_row6_col2{
#             background-color:  #67aa84;
#             color:  #000000;
#         }#T_459ea_row6_col3,#T_459ea_row9_col3{
#             background-color:  #afd2bd;
#             color:  #000000;
#         }#T_459ea_row6_col4{
#             background-color:  #5da57c;
#             color:  #000000;
#         }#T_459ea_row7_col1{
#             background-color:  #4e9c70;
#             color:  #000000;
#         }#T_459ea_row7_col2{
#             background-color:  #3d9363;
#             color:  #000000;
#         }#T_459ea_row7_col4{
#             background-color:  #3b9261;
#             color:  #000000;
#         }#T_459ea_row7_col6{
#             background-color:  #7ab493;
#             color:  #000000;
#         }#T_459ea_row7_col7,#T_459ea_row8_col1,#T_459ea_row8_col7,#T_459ea_row9_col4,#T_459ea_row9_col7{
#             background-color:  #4c9c6f;
#             color:  #000000;
#         }#T_459ea_row8_col0{
#             background-color:  #539f74;
#             color:  #000000;
#         }#T_459ea_row8_col6{
#             background-color:  #a7cdb7;
#             color:  #000000;
#         }#T_459ea_row9_col0{
#             background-color:  #63a881;
#             color:  #000000;
#         }#T_459ea_row9_col1{
#             background-color:  #73b18e;
#             color:  #000000;
#         }#T_459ea_row9_col2{
#             background-color:  #4b9b6e;
#             color:  #000000;
#         }#T_459ea_row9_col6{
#             background-color:  #72b08d;
#             color:  #000000;
#         }#T_459ea_row10_col0{
#             background-color:  #82b99a;
#             color:  #000000;
#         }#T_459ea_row10_col1{
#             background-color:  #dfece4;
#             color:  #000000;
#         }#T_459ea_row10_col3{
#             background-color:  #c5decf;
#             color:  #000000;
#         }#T_459ea_row11_col0{
#             background-color:  #bdd9c9;
#             color:  #000000;
#         }#T_459ea_row11_col3{
#             background-color:  #c1dccc;
#             color:  #000000;
#         }#T_459ea_row11_col4{
#             background-color:  #b6d6c3;
#             color:  #000000;
#         }#T_459ea_row11_col6{
#             background-color:  #9fc9b1;
#             color:  #000000;
#         }</style><table id="T_459ea_" ><thead>    <tr>        <th class="index_name level0" >label_type</th>        <th class="col_heading level0 col0" >Forums</th>        <th class="col_heading level0 col1" >Personal</th>        <th class="col_heading level0 col2" >Promotions</th>        <th class="col_heading level0 col3" >Purchases</th>        <th class="col_heading level0 col4" >Social</th>        <th class="col_heading level0 col5" >Spam</th>        <th class="col_heading level0 col6" >Travel</th>        <th class="col_heading level0 col7" >Updates</th>    </tr>    <tr>        <th class="index_name level0" >month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_459ea_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_459ea_row0_col0" class="data row0 col0" >10%</td>
#                         <td id="T_459ea_row0_col1" class="data row0 col1" >8%</td>
#                         <td id="T_459ea_row0_col2" class="data row0 col2" >7%</td>
#                         <td id="T_459ea_row0_col3" class="data row0 col3" >6%</td>
#                         <td id="T_459ea_row0_col4" class="data row0 col4" >7%</td>
#                         <td id="T_459ea_row0_col5" class="data row0 col5" ></td>

# %%
#creating a feature for Spam emails
df['spam_month'] = np.where(df.month.isin([10]), 1, 0)


# #### Org Classification


#reading a csv org_classification file created to classify orgs into labels they appeared most in
org_class = pd.read_csv('org_classification.csv')
df = pd.merge(df, org_class, how = 'left', on = 'org')
df['org_class'].fillna('Others', inplace = True)

# %%
# Train Data
df[~df['label'].isna()]['org_class'].value_counts(normalize = True)

# Test Data
df[df['label'].isna()]['org_class'].value_counts(normalize = True)
# Out:
# Others        0.304787
# Personal      0.298327
# Updates       0.140754
# Social        0.105660
# Promotions    0.066521
# Purchases     0.051564
# Forums        0.022639
# Spam          0.005849
# Travel        0.003899
# Name: org_class, dtype: float64

# %%
color_format(df.groupby('label_type')['org_class'].value_counts(normalize = True).unstack().transpose(), "{:.0%}")
# Out:
# <style  type="text/css" >
# #T_675e8_row0_col0{
#             background-color:  #dae9e0;
#             color:  #000000;
#         }#T_675e8_row0_col1,#T_675e8_row2_col4,#T_675e8_row5_col7{
#             background-color:  #e9f1eb;
#             color:  #000000;
#         }#T_675e8_row0_col2,#T_675e8_row0_col3,#T_675e8_row0_col4,#T_675e8_row0_col5,#T_675e8_row0_col6,#T_675e8_row3_col0,#T_675e8_row3_col5,#T_675e8_row3_col6,#T_675e8_row4_col0,#T_675e8_row4_col4,#T_675e8_row4_col6,#T_675e8_row5_col0,#T_675e8_row5_col3,#T_675e8_row5_col5,#T_675e8_row5_col6,#T_675e8_row6_col0,#T_675e8_row6_col3,#T_675e8_row6_col4,#T_675e8_row6_col6,#T_675e8_row7_col0,#T_675e8_row7_col3,#T_675e8_row7_col4,#T_675e8_row7_col5,#T_675e8_row8_col0,#T_675e8_row8_col4,#T_675e8_row8_col5,#T_675e8_row8_col6{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_675e8_row0_col7{
#             background-color:  #e8f1eb;
#             color:  #000000;
#         }#T_675e8_row1_col0,#T_675e8_row2_col5,#T_675e8_row2_col6,#T_675e8_row3_col3,#T_675e8_row3_col4,#T_675e8_row6_col1,#T_675e8_row6_col7,#T_675e8_row7_col1,#T_675e8_row7_col2,#T_675e8_row7_col7{
#             background-color:  #ebf3ed;
#             color:  #000000;
#         }#T_675e8_row1_col1{
#             background-color:  #55a076;
#             color:  #000000;
#         }#T_675e8_row1_col2,#T_675e8_row1_col7,#T_675e8_row2_col0,#T_675e8_row2_col1,#T_675e8_row4_col3,#T_675e8_row5_col4,#T_675e8_row6_col5,#T_675e8_row7_col6{
#             background-color:  #2e8b57;
#             color:  #000000;
#         }#T_675e8_row1_col3{
#             background-color:  #c8dfd2;
#             color:  #000000;
#         }#T_675e8_row1_col4{
#             background-color:  #dbeae1;
#             color:  #000000;
#         }#T_675e8_row1_col5{
#             background-color:  #d4e6db;
#             color:  #000000;
#         }#T_675e8_row1_col6{
#             background-color:  #a8ceb8;
#             color:  #000000;
#         }#T_675e8_row2_col2,#T_675e8_row2_col3{
#             background-color:  #e7f0ea;
#             color:  #000000;
#         }#T_675e8_row2_col7{
#             background-color:  #deece3;
#             color:  #000000;
#         }#T_675e8_row3_col1{
#             background-color:  #cde2d6;
#             color:  #000000;
#         }#T_675e8_row3_col2{
#             background-color:  #66a983;
#             color:  #000000;
#         }#T_675e8_row3_col7{
#             background-color:  #e3eee7;
#             color:  #000000;
#         }#T_675e8_row4_col1{
#             background-color:  #d3e6da;
#             color:  #000000;
#         }#T_675e8_row4_col2{
#             background-color:  #aacfb9;
#             color:  #000000;
#         }#T_675e8_row4_col5{
#             background-color:  #c3ddcd;
#             color:  #000000;
#         }#T_675e8_row4_col7{
#             background-color:  #ddebe2;
#             color:  #000000;
#         }#T_675e8_row5_col1{
#             background-color:  #bdd9c9;
#             color:  #000000;
#         }#T_675e8_row5_col2,#T_675e8_row8_col3{
#             background-color:  #e6f0e9;
#             color:  #000000;
#         }#T_675e8_row6_col2{
#             background-color:  #e5efe9;
#             color:  #000000;
#         }#T_675e8_row8_col1{
#             background-color:  #afd2bd;
#             color:  #000000;
#         }#T_675e8_row8_col2{
#             background-color:  #d8e8de;
#             color:  #000000;
#         }#T_675e8_row8_col7{
#             background-color:  #55a176;
#             color:  #000000;
#         }</style><table id="T_675e8_" ><thead>    <tr>        <th class="index_name level0" >label_type</th>        <th class="col_heading level0 col0" >Forums</th>        <th class="col_heading level0 col1" >Personal</th>        <th class="col_heading level0 col2" >Promotions</th>        <th class="col_heading level0 col3" >Purchases</th>        <th class="col_heading level0 col4" >Social</th>        <th class="col_heading level0 col5" >Spam</th>        <th class="col_heading level0 col6" >Travel</th>        <th class="col_heading level0 col7" >Updates</th>    </tr>    <tr>        <th class="index_name level0" >org_class</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_675e8_level0_row0" class="row_heading level0 row0" >Forums</th>
#                         <td id="T_675e8_row0_col0" class="data row0 col0" >12%</td>
#                         <td id="T_675e8_row0_col1" class="data row0 col1" >1%</td>
#                         <td id="T_675e8_row0_col2" class="data row0 col2" ></td>
#                         <td id="T_675e8_row0_col3" class="data row0 col3" ></td>
#                         <td id="T_675e8_row0_col4" class="data row0 col4" ></td>
#                         <td id="T_675e8_row0_col5" class="data row0 col5" ></td>
#                         <td id="T_675e8_row0_col6" class="data row0 col6" ></td>
#                         <td id="T_675e8_row0_col7" class="data row0 col7" >1%</td>
#             </tr>
#             <tr>
#                         <th id="T_675e8_level0_row1" class="row_heading level0 row1" >Others</th>
#                         <td id="T_675e8_row1_col0" class="data row1 col0" >4%</td>
#                         <td id="T_675e8_row1_col1" class="data row1 col1" >30%</td>
#                         <td id="T_675e8_row1_col2" class="data row1 col2" >45%</td>
#                         <td id="T_675e8_row1_col3" class="data row1 col3" >15%</td>
#                         <td id="T_675e8_row1_col4" class="data row1 col4" >8%</td>
#                         <td id="T_675e8_row1_col5" class="data row1 col5" >11%</td>
#                         <td id="T_675e8_row1_col6" class="data row1 col6" >31%</td>
#                         <td id="T_675e8_row1_col7" class="data row1 col7" >47%</td>
#             </tr>
#             <tr>
#                         <th id="T_675e8_level0_row2" class="row_heading level0 row2" >Personal</th>
#                         <td id="T_675e8_row2_col0" class="data row2 col0" >84%</td>
#                         <td id="T_675e8_row2_col1" class="data row2 col1" >37%</td>
#                         <td id="T_675e8_row2_col2" class="data row2 col2" >1%</td>
#                         <td id="T_675e8_row2_col3" class="data row2 col3" >2%</td>
#                         <td id="T_675e8_row2_col4" class="data row2 col4" >1%</td>
#                         <td id="T_675e8_row2_col5" class="data row2 col5" >3%</td>
#                         <td id="T_675e8_row2_col6" class="data row2 col6" >23%</td>
#                         <td id="T_675e8_row2_col7" class="data row2 col7" >4%</td>
#             </tr>
#             <tr>
#                         <th id="T_675e8_level0_row3" class="row_heading level0 row3" >Promotions</th>
#                         <td id="T_675e8_row3_col0" class="data row3 col0" ></td>
#                         <td id="T_675e8_row3_col1" class="data row3 col1" >6%</td>
#                         <td id="T_675e8_row3_col2" class="data row3 col2" >31%</td>
#                         <td id="T_675e8_row3_col3" class="data row3 col3" >0%</td>
#                         <td id="T_675e8_row3_col4" class="data row3 col4" >0%</td>
#                         <td id="T_675e8_row3_col5" class="data row3 col5" ></td>
#                         <td id="T_675e8_row3_col6" class="data row3 col6" ></td>
#                         <td id="T_675e8_row3_col7" class="data row3 col7" >3%</td>
#             </tr>
#             <tr>
#                         <th id="T_675e8_level0_row4" class="row_heading level0 row4" >Purchases</th>
#                         <td id="T_675e8_row4_col0" class="data row4 col0" ></td>
#                         <td id="T_675e8_row4_col1" class="data row4 col1" >5%</td>
#                         <td id="T_675e8_row4_col2" class="data row4 col2" >15%</td>
#                         <td id="T_675e8_row4_col3

# %%
#cleaning mail_type
df['mail_type'] = df.mail_type.str.lower().str.strip()
df['mail_type'] = df.mail_type.fillna('unspecified')
color_format(df.groupby('label_type')['mail_type'].value_counts(normalize = True).unstack().transpose(), "{:.0%}")
# Out:
# <style  type="text/css" >
# #T_cde87_row0_col0,#T_cde87_row0_col1,#T_cde87_row0_col2,#T_cde87_row0_col3,#T_cde87_row0_col4,#T_cde87_row0_col5,#T_cde87_row0_col7,#T_cde87_row2_col6{
#             background-color:  #2e8b57;
#             color:  #000000;
#         }#T_cde87_row0_col6{
#             background-color:  #acd0bb;
#             color:  #000000;
#         }#T_cde87_row1_col0,#T_cde87_row1_col2,#T_cde87_row1_col3,#T_cde87_row1_col4,#T_cde87_row1_col5,#T_cde87_row1_col6,#T_cde87_row1_col7,#T_cde87_row3_col3,#T_cde87_row3_col4,#T_cde87_row3_col5,#T_cde87_row4_col0,#T_cde87_row4_col2,#T_cde87_row4_col3,#T_cde87_row4_col4,#T_cde87_row4_col5,#T_cde87_row4_col6,#T_cde87_row4_col7,#T_cde87_row5_col0,#T_cde87_row5_col2,#T_cde87_row5_col3,#T_cde87_row5_col4,#T_cde87_row5_col5,#T_cde87_row5_col6,#T_cde87_row5_col7,#T_cde87_row6_col0,#T_cde87_row6_col2,#T_cde87_row6_col3,#T_cde87_row6_col4,#T_cde87_row6_col5,#T_cde87_row6_col6,#T_cde87_row6_col7,#T_cde87_row9_col0,#T_cde87_row9_col2,#T_cde87_row9_col3,#T_cde87_row9_col4,#T_cde87_row9_col5,#T_cde87_row9_col6{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_cde87_row1_col1,#T_cde87_row3_col6,#T_cde87_row4_col1,#T_cde87_row5_col1,#T_cde87_row6_col1,#T_cde87_row8_col0,#T_cde87_row8_col2,#T_cde87_row8_col3,#T_cde87_row8_col4,#T_cde87_row8_col5,#T_cde87_row9_col1,#T_cde87_row9_col7{
#             background-color:  #ebf3ed;
#             color:  #000000;
#         }#T_cde87_row2_col0{
#             background-color:  #d5e7dc;
#             color:  #000000;
#         }#T_cde87_row2_col1{
#             background-color:  #d3e5da;
#             color:  #000000;
#         }#T_cde87_row2_col2{
#             background-color:  #dbeae1;
#             color:  #000000;
#         }#T_cde87_row2_col3{
#             background-color:  #cfe3d7;
#             color:  #000000;
#         }#T_cde87_row2_col4,#T_cde87_row7_col0{
#             background-color:  #e5efe9;
#             color:  #000000;
#         }#T_cde87_row2_col5{
#             background-color:  #e7f0ea;
#             color:  #000000;
#         }#T_cde87_row2_col7{
#             background-color:  #deece3;
#             color:  #000000;
#         }#T_cde87_row3_col0{
#             background-color:  #e0ece4;
#             color:  #000000;
#         }#T_cde87_row3_col1{
#             background-color:  #e4efe8;
#             color:  #000000;
#         }#T_cde87_row3_col2,#T_cde87_row7_col4{
#             background-color:  #e9f2ec;
#             color:  #000000;
#         }#T_cde87_row3_col7{
#             background-color:  #e9f1eb;
#             color:  #000000;
#         }#T_cde87_row7_col1{
#             background-color:  #d3e6da;
#             color:  #000000;
#         }#T_cde87_row7_col2{
#             background-color:  #c4ddce;
#             color:  #000000;
#         }#T_cde87_row7_col3{
#             background-color:  #c7dfd1;
#             color:  #000000;
#         }#T_cde87_row7_col5{
#             background-color:  #cde2d5;
#             color:  #000000;
#         }#T_cde87_row7_col6{
#             background-color:  #70af8b;
#             color:  #000000;
#         }#T_cde87_row7_col7{
#             background-color:  #9dc8af;
#             color:  #000000;
#         }#T_cde87_row8_col1{
#             background-color:  #e1ede5;
#             color:  #000000;
#         }#T_cde87_row8_col6{
#             background-color:  #e8f1eb;
#             color:  #000000;
#         }#T_cde87_row8_col7{
#             background-color:  #deebe3;
#             color:  #000000;
#         }</style><table id="T_cde87_" ><thead>    <tr>        <th class="index_name level0" >label_type</th>        <th class="col_heading level0 col0" >Forums</th>        <th class="col_heading level0 col1" >Personal</th>        <th class="col_heading level0 col2" >Promotions</th>        <th class="col_heading level0 col3" >Purchases</th>        <th class="col_heading level0 col4" >Social</th>        <th class="col_heading level0 col5" >Spam</th>        <th class="col_heading level0 col6" >Travel</th>        <th class="col_heading level0 col7" >Updates</th>    </tr>    <tr>        <th class="index_name level0" >mail_type</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cde87_level0_row0" class="row_heading level0 row0" >multipart/alternative</th>
#                         <td id="T_cde87_row0_col0" class="data row0 col0" >74%</td>
#                         <td id="T_cde87_row0_col1" class="data row0 col1" >74%</td>
#                         <td id="T_cde87_row0_col2" class="data row0 col2" >77%</td>
#                         <td id="T_cde87_row0_col3" class="data row0 col3" >74%</td>
#                         <td id="T_cde87_row0_col4" class="data row0 col4" >95%</td>
#                         <td id="T_cde87_row0_col5" class="data row0 col5" >76%</td>
#                         <td id="T_cde87_row0_col6" class="data row0 col6" >17%</td>
#                         <td id="T_cde87_row0_col7" class="data row0 col7" >63%</td>
#             </tr>
#             <tr>
#                         <th id="T_cde87_level0_row1" class="row_heading level0 row1" >multipart/idm</th>
#                         <td id="T_cde87_row1_col0" class="data row1 col0" ></td>
#                         <td id="T_cde87_row1_col1" class="data row1 col1" >0%</td>
#                         <td id="T_cde87_row1_col2" class="data row1 col2" ></td>
#                         <td id="T_cde87_row1_col3" class="data row1 col3" ></td>
#                         <td id="T_cde87_row1_col4" class="data row1 col4" ></td>
#                         <td id="T_cde87_row1_col5" class="data row1 col5" ></td>
#                         <td id="T_cde87_row1_col6" class="data row1 col6" ></td>
#                         <td id="T_cde87_row1_col7" class="data row1 col7" ></td>
#             </tr>
#             <tr>
#                         <th id="T_cde87_level0_row2" class="row_heading level0 row2" >multipart/mixed</th>
#                         <td id="T_cde87_row2_col0" class="data row2 col0" >11%</td>
#                         <td id="T_cde87_row2_col1" class="data row2 col1" >10%</td>
#                         <td id="T_cde87_row2_col2" class="data row2 col2" >7%</td>
#                         <td id="T_cde87_row2_col3" class="data row2 col3" >11%</td>
#                         <td id="T_cde87_row2_col4" class="data row2 col4" >3%</td>
#                         <td id="T_cde87_row2_col5" class="data row2 col5" >5%</td>
#                         <td id="T_cde87_row2_col6" class="data row2 col6" >47%</td>
#                         <td id="T_cde87_row2_col7" class="data row2 col7" >5%</td>
#             </tr>
#             <tr>
#                         <th id="T_cde87_level0_row3" class="row_heading level0 row3" >multipart/related</th>
#                         <td id="T_cde87_row3_col0" class="data row3 col0" >7%</td>
#                         <td id="T_cde87_row3_col1" class="data row3 col1" >3%</td>
#                         <td id="T_cde87_row3_col2" class="data row3 col2" >1%</td>
#                         <td id="T_cde87_row3_col3" class="data row3 col3" ></td>
#                         <td id="T_cde87_row3_col4" class="data row3 col4" ></td>
#                         <td id="T_cde87_row3_col5" class="data row3 col5" ></td>
#                         <td id="T_cde87_row3_col6" class="data row3 col6" >2%</td>
#                         <td id="T_cde87_row3_col7" class="data row3 col7" >1%</td>
#             </tr>
#             <tr>
#                         <th id="T_cde87_level0_row4" class="row_heading level0 row4" >multipart/report</th>
#                         <td id="T_cde87_row4_col0" class="data row4 col0" ></td>
#                         <td id="T_cde87_row4_col1" class="data row4 col1" >0%</td>
#                         <td id="T_cde87_row4_col2" class="data row4 col2" ></td>

# %%
#creating a feature website by combining org and tld and taking out frequencies for website, mail_type, orgs, and tld
df.loc[:,"website"]=df.loc[:,"org"].fillna('NA')  + df.loc[:,"tld"].fillna('NA')
org_freq=df.groupby("website").size()/len(df)
df.loc[:,"website_freq"]=df.loc[:,"website"].map(org_freq)


mail_freq=df.groupby("mail_type").size()/len(df)
df.loc[:,"mail_type_freq"]=df.loc[:,"mail_type"].map(mail_freq)


df.loc[:,"org_freq"]=df.loc[:,"org"].fillna('NA')
org_freq=df.groupby("org_freq").size()/len(df)
df.loc[:,"org_freq"]=df.loc[:,"org_freq"].map(org_freq)


df.loc[:,"tld_freq"]=df.loc[:,"tld"].fillna('NA')
org_freq=df.groupby("tld_freq").size()/len(df)
df.loc[:,"tld_freq"]=df.loc[:,"tld_freq"].map(org_freq)

# %%
#defining a feature to identify travel mails
df['travel_mail_type'] = np.where(df.mail_type.isin(['multipart/mixed']), 1, 0)


# #### Characters in Subject & Body

# In[25]:


df['chars_in_subject'] = df.chars_in_subject.fillna(0)
df['chars_in_body'] = df.chars_in_body.fillna(0)

# %%
#OneHotEncoding
df = pd.get_dummies(df, columns = ['org_class', 'timezone', 'mail_type'])
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'org', 'tld', 'ccs', 'bcced', 'images', 'urls',
#        'salutations', 'designation', 'chars_in_subject', 'chars_in_body',
#        'label', 'label_type', 'local_date', 'day', 'weekday', 'weekend',
#        'month', 'hour', 'minutes', 'seconds', 'promotion_hour', 'spam_hour',
#        'travel_hour', 'spam_month', 'website', 'website_freq',
#        'mail_type_freq', 'org_freq', 'tld_freq', 'travel_mail_type',
#        'org_class_Forums', 'org_class_Others', 'org_class_Personal',
#        'org_class_Promotions', 'org_class_Purchases', 'org_class_Social',
#        'org_class_Spam', 'org_class_Travel', 'org_class_Updates',
#        'timezone_+0000', 'timezone_+0100', 'timezone_+0200', 'timezone_+0300',
#        'timezone_+0330', 'timezone_+0400', 'timezone_+0430', 'timezone_+0500',
#        'timezone_+0530', 'timezone_+0545', 'timezone_+0580', 'timezone_+0600',
#        'timezone_+0700', 'timezone_+0800', 'timezone_+0900', 'timezone_+1000',
#        'timezone_+1100', 'timezone_-0300', 'timezone_-0400', 'timezone_-0500',
#        'timezone_-0600', 'timezone_-0700', 'timezone_-0800',
#        'timezone_unspecified', 'mail_type_multipart/alternative',
#        'mail_type_multipart/idm', 'mail_type_multipart/mixed',
#        'mail_type_multipart/related', 'mail_type_multipart/report',
#        'mail_type_multipart/signed', 'mail_type_text/calendar',
#        'mail_type_text/html', 'mail_type_text/plain', 'mail_type_unspecified'],
#       dtype='object')

# %%
#function to split training data into training set and validation set
def train_val_split(data):

    val_set = []
    for label in range(0, 8):
        val_data = data[data['label'] == label].sample(frac = 0.2, random_state = 0)
        val_set.append(val_data)
    
    val = pd.concat(val_set)
    train = data[~(data.index.isin(val.index))]
    
    return(train, val)

# %%
#creating a list which mentions which features to remove
remove_features = [
    'label',
    'mail_type_multipart/signed',
    'mail_type_unspecified',
    'mail_type_multipart/report',
    'mail_type_text/calendar',
    'mail_type_multipart/idm',
    'timezone_+0330',
    'timezone_+0430',
    'timezone_+0580',
    'timezone_+0545',
    'timezone_+0600',
    'timezone_+1000',
    'timezone_+0700',
    'timezone_+0400',
    'timezone_+0900',
    'timezone_-0300',
    'timezone_+0500',
    'timezone_+1100',
    'timezone_+0300',
    'timezone_+0800',
    'timezone_-0400',
    'timezone_+0100',
    'timezone_-0500',
    'timezone_-0600',
    'timezone_-0700',
    'timezone_+0200',
    'timezone_-0800',
    'designation', 'weekend', 'promotion_hour', 'travel_hour',
       'mail_type_text/plain', 'spam_hour', 'mail_type_multipart/related',
       'bcced', 'timezone_unspecified', 'mail_type_multipart/idm', 'mail_type_multipart/related',
       'mail_type_multipart/report', 'mail_type_multipart/signed',
       'mail_type_text/calendar',
       'mail_type_text/plain', 'mail_type_unspecified',
    'chars_in_subject','chars_in_body',
    'seconds','minutes',
    'travel_mail_type','spam_month'
    


]

# %%
train_df, val_df = train_val_split(data = df[~df['label'].isna()])
print('Train Data:', train_df.shape)
print('Validation Data:', val_df.shape)

features = list(set(df.select_dtypes(include = np.number).columns)- set(remove_features))

X, y, X_val, y_val = train_df[features], train_df['label'], val_df[features], val_df['label']

print('Train Data:', X.shape)
print('Validation Data:', X_val.shape)
# Out:
# Train Data: (64143, 75)
# Validation Data: (16033, 75)
# Train Data: (64143, 27)
# Validation Data: (16033, 27)

# %%
#training the first model only on label 1
df_copy = train_df.copy()
df_copy.loc[df_copy['label']!=1,'label']  = 0
df_copy['label'].value_counts()


clf_class_1 = CatBoostClassifier(n_estimators = 1000,
                       learning_rate = 0.05,
                       rsm = 0.2, ## Analogous to colsample_bytree
                       random_state=0,
                         max_depth =6,
                         verbose = 0,
                        auto_class_weights = 'SqrtBalanced',
                        eval_metric = 'F1'
                        
                                 
#                                  L2, Cosine, NewtonL2, NewtonCosine
                     )
clf_class_1.fit(df_copy[features], df_copy['label'])

y_pred_train = (clf_class_1.predict_proba(df_copy[features])[:,1] >= 0.5).astype(int) 

print('\nTrain F1 Score:', f1_score(df_copy['label'], y_pred_train, average = 'macro'))
print('\nTrain Report: \n', classification_report(df_copy['label'], y_pred_train))
#print('Test Report: \n', classification_report(y_val, y_pred_val))
# Out:
# Train F1 Score: 0.6567796104289905
#
# Train Report:
#                precision    recall  f1-score   support
#
#          0.0       0.66      0.76      0.71     34387
#          1.0       0.67      0.56      0.61     29756
#
#     accuracy                           0.66     64143
#    macro avg       0.66      0.66      0.66     64143
# weighted avg       0.66      0.66      0.66     64143

# %%
#Training the second class on all other labels except 1
df_oth_class = train_df[~(train_df['label'].isin([1]))].copy()

clf_oth_class = CatBoostClassifier(n_estimators = 1000,
                       learning_rate = 0.05,
                       rsm = 0.2, ## Analogous to colsample_bytree
                       random_state=0,
                         max_depth =6,
                         verbose = 0,
                         auto_class_weights = 'SqrtBalanced',
                         
                     )
clf_oth_class.fit(df_oth_class[features], df_oth_class['label'])

y_pred_train = clf_oth_class.predict(df_oth_class[features])

print('\nTrain F1 Score:', f1_score(df_oth_class['label'], y_pred_train, average = 'macro'))
print('\nTrain Report: \n', classification_report(df_oth_class['label'], y_pred_train))
# Out:
# Train F1 Score: 0.8146154914537732
#
# Train Report:
#                precision    recall  f1-score   support
#
#          0.0       0.93      0.89      0.91     14396
#          2.0       0.86      0.84      0.85      6854
#          3.0       0.99      0.99      0.99      8582
#          4.0       0.45      0.98      0.62       286
#          5.0       0.54      1.00      0.70       113
#          6.0       0.51      1.00      0.67       122
#          7.0       0.94      0.99      0.97      4034
#
#     accuracy                           0.92     34387
#    macro avg       0.74      0.96      0.81     34387
# weighted avg       0.92      0.92      0.92     34387

# %%
#testing the data on validation set using the two stacked models
val_predict = []
for i in val_df.index:
    class1 = clf_class_1.predict(val_df[val_df.index==i][features])[0]
    if class1 ==1:
        val_predict.append(class1)
    else:
        oth_class = clf_oth_class.predict(val_df[val_df.index==i][features])[0][0]
        val_predict.append(oth_class)

# %%
print('Validation F1 Score:', f1_score(y_val, val_predict, average = 'macro'))
print('Test Report: \n', classification_report(y_val, val_predict))
# Out:
# Validation F1 Score: 0.5279218696507064
# Test Report:
#                precision    recall  f1-score   support
#
#          0.0       0.57      0.62      0.59      3599
#          1.0       0.60      0.50      0.55      7439
#          2.0       0.48      0.61      0.54      1713
#          3.0       0.66      0.55      0.60      2145
#          4.0       0.28      0.77      0.41        71
#          5.0       0.20      0.39      0.27        28
#          6.0       0.46      0.87      0.60        30
#          7.0       0.54      0.87      0.67      1008
#
#     accuracy                           0.57     16033
#    macro avg       0.47      0.65      0.53     16033
# weighted avg       0.58      0.57      0.57     16033

# %%
feature_importance = pd.Series(clf_class_1.feature_importances_, index = features).sort_values(ascending = False).round(2)
feature_importance
# Out:
# org_freq                           9.91
# website_freq                       9.61
# tld_freq                           8.58
# urls                               7.61
# org_class_Forums                   6.65
# images                             6.55
# ccs                                6.13
# month                              6.10
# org_class_Personal                 5.33
# Unnamed: 0                         4.22
# timezone_+0000                     3.80
# hour                               3.29
# mail_type_text/html                2.75
# timezone_+0530                     2.66
# mail_type_freq                     2.61
# day                                2.21
# org_class_Updates                  2.19
# salutations                        2.01
# weekday                            1.81
# mail_type_multipart/alternative    1.73
# org_class_Others                   1.51
# mail_type_multipart/mixed          1.00
# org_class_Spam                     0.52
# org_class_Promotions               0.36
# org_class_Social                   0.33
# org_class_Purchases                0.26
# org_class_Travel                   0.25
# dtype: float64

# %%
feature_importance = pd.Series(clf_oth_class.feature_importances_, index = features).sort_values(ascending = False).round(2)
feature_importance
# Out:
# website_freq                       10.22
# org_freq                            8.35
# urls                                8.26
# month                               6.88
# images                              6.58
# tld_freq                            5.37
# org_class_Social                    5.17
# org_class_Others                    5.15
# timezone_+0000                      4.96
# hour                                3.94
# org_class_Purchases                 3.79
# day                                 3.13
# salutations                         3.09
# timezone_+0530                      2.98
# org_class_Updates                   2.97
# weekday                             2.47
# Unnamed: 0                          2.42
# mail_type_multipart/alternative     2.36
# org_class_Personal                  2.08
# mail_type_freq                      1.97
# ccs                                 1.63
# mail_type_text/html                 1.52
# org_class_Promotions                1.52
# mail_type_multipart/mixed           1.10
# org_class_Spam                      0.79
# org_class_Forums                    0.76
# org_class_Travel                    0.54
# dtype: float64

# %%
#Predicting test data set
test_df = df[df['label'].isna()]


val_predict = []
for i in test_df.index:
    class1 = clf_class_1.predict(test_df[test_df.index==i][features])[0]
    if class1 ==1:
        val_predict.append(class1)
    else:
        oth_class = clf_oth_class.predict(test_df[test_df.index==i][features])[0][0]
        val_predict.append(oth_class)

# %%
len(val_predict)
# Out:
# 34365

# %%
pred_df = pd.DataFrame(val_predict, columns=['label'])
pred_df['label'] = pred_df['label'].astype(int)
#pred_df.to_csv("stack_cat_boost_submission.csv", index=True, index_label='Id')

# %%
pred_df['label'].unique()
# Out:
# array([1, 0, 7, 2, 3, 4, 5, 6])
